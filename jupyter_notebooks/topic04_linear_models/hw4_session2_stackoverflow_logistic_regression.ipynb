# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg">
# ## Открытый курс по машинному обучению. Сессия № 2
# Авторы материала: Павел Нестеров. Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# # <center> Домашняя работа №4
# ## <center> Логистическая регрессия в задаче тегирования вопросов StackOverflow
#
# **Надо вывести формулы, где это просится (да, ручка и бумажка), заполнить код в клетках и выбрать ответы в [веб-форме](https://docs.google.com/forms/d/1I_ticU8rpeoGJjsBUcaInpvgdxdq60hV7IcSvo4rlGo/).**
#
# ## 0. Описание задачи
#
# В этой домашней работе мы с вами изучим и запрограммируем модель для прогнозирования тегов по тексту вопроса на базе многоклассовой логистической регрессии. В отличие от обычной постановки задачи классификации (multiclass), в данном случае один пример может принадлежать одновременно к нескольким классам (multilabel). Мы будем реализовывать онлайн версию алгоритма мультиклассовой классификации.
#
# Мы будем использовать небольшую выборку из протеггированных вопросов с сайта StackOverflow размером в 125 тысяч примеров (около 150 Мб, скачайте по [этой](https://drive.google.com/open?id=0B4bl7YMqDnViYVo0V2FubFVhMFE) ссылке).
#
# PS: Можно показать, что такая реализация совсем не эффективная и проще было бы использовать векторизированные вычисления. Для данного датасета так и есть. Но на самом деле подобные реализации используются в жизни, но естественно, написаны они не на Python. Например, в онлайн моделях прогнозирования [CTR](https://en.wikipedia.org/wiki/Click-through_rate) юзеру показывается баннер, затем в зависимости от наличия клика происходит обновление параметров модели. В реальной жизни параметров модели может быть несколько сотен миллионов, а у юзера из этих ста миллионов от силы сто или тысяча параметров отличны от нуля, векторизировать такие вычисления не очень эффективно. Обычно все это хранится в огромных кластерах в in-memory базах данных, а обработка пользователей происходит распределенно.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")
plt.rcParams['figure.figsize'] = 16, 12
from tqdm import tqdm_notebook
import pandas as pd
from collections import defaultdict

# поменяйте на свой путь
DS_FILE_NAME = '../../data/data.hw4/stackoverflow_sample_125k.tsv'
TAGS_FILE_NAME = '../../data/data.hw4/top10_tags.tsv'

# %%
top_tags = []
with open(TAGS_FILE_NAME, 'r') as f:
    for line in f:
        top_tags.append(line.strip())
top_tags = set(top_tags)
print(top_tags)
# Out:
# {'java', 'html', 'javascript', 'jquery', 'c#', 'ios', 'python', 'c++', 'android', 'php'}

# %% [markdown]
# ## 1. Многоклассовая логистическая регрессия
#
# Вспомним, как получается логистическая регрессия для двух классов $\left\{0, 1\right\}$, вероятность принадлежности объекта к классу $1$ выписывается по теореме Байеса:
#
# $$\large \begin{array}{rcl}
# p\left(c = 1 \mid \vec{x}\right) &=& \dfrac{p\left(\vec{x} \mid c = 1\right)p\left(c = 1\right)}{p\left(\vec{x} \mid c = 1\right)p\left(c = 1\right) + p\left(\vec{x} \mid c = 0\right)p\left(c = 0\right)} \\
# &=& \dfrac{1}{1 + e^{-a}} \\
# &=& \sigma\left(a\right)
# \end{array}$$
# где:
# - $\vec{x}$ – вектор признаков объекта
# - $\sigma$ – обозначение функции логистического сигмоида при скалярном аргументе
# - $a = \log \frac{p\left(\vec{x} \mid c = 1\right)p\left(c = 1\right)}{p\left(\vec{x} \mid c = 0\right)p\left(c = 0\right)} = \sum_{i=0}^M w_i x^i$ – это отношение мы моделируем линейной функцией от признаков объекта и параметров модели
#
# Данное выражение легко обобщить до множества из $K$ классов, изменится только знаменатель в формуле Байеса. Запишем вероятность принадлежности объекта к классу $k$:
# $$\large \begin{array}{rcl}
# p\left(c = k \mid \vec{x}\right) &=& \dfrac{p\left(\vec{x} \mid c = k\right)p\left(c = k\right)}{\sum_{i=1}^K p\left(\vec{x} \mid c = i\right)p\left(c = i\right)} \\
# &=& \dfrac{e^{z_k}}{\sum_{i=1}^{K}e^{z_i}} \\
# &=& \sigma_k\left(\vec{z}\right)
# \end{array}$$
# где:
# - $\sigma_k$ – обозначение функции softmax при векторном аргументе
# - $z_k = \log p\left(\vec{x} \mid c = k\right)p\left(c = k\right) = \sum_{i=0}^M w_{ki} x^i$ – это выражение моделируется линейной функций от признаков объекта и параметров класса $k$
#
# Для моделирования полного правдоподобия примера мы используем [категориальное распределение](https://en.wikipedia.org/wiki/Categorical_distribution), а лучше его логарифм (для удобства):
#
# $$\large \begin{array}{rcl}
# \mathcal{L} = \log p\left({\vec{x}}\right) &=& \log \prod_{i=1}^K \sigma_i\left(\vec{z}\right)^{y_i} \\
# &=& \sum_{i=1}^K y_i \log \sigma_i\left(\vec{z}\right)
# \end{array}$$
#
# Получается хорошо знакомая нам функция [cross entropy](https://en.wikipedia.org/wiki/Cross_entropy) (если домножить на $-1$). Правдоподобие нужно максимизировать, а, соответственно, перекрестную энтропию нужно минимизировать. Продифференцировав по параметрам модели, мы _легко_ получим правила обновления весов для градиентного спуска, **проделайте этот вывод, если вы его не делали** (если вы вдруг сдались, то на [этом](https://www.youtube.com/watch?v=-WiR16raQf4) видео есть разбор вывода, понимание этого вам понадобится для дальнейшего выполнения задания):
#
# $$\large \begin{array}{rcl}
# \frac{\partial \mathcal{L}}{\partial w_{km}} &=& x_m \left(y_k - \sigma_k\left(\vec{z}\right)\right)
# \end{array}$$
#
# В стандартной формулировке получается, что вектор $\left(\sigma_1, \sigma_2, \ldots, \sigma_K\right)$ образует дискретное вероятностное распределение, т.е. $\sum_{i=1}^K \sigma_i = 1$. Но в нашей постановке задачи каждый пример может иметь несколько тегов или одновременно принадлежать к нескольким классам. Для этого мы немного изменим модель:
# - будем считать, что все теги независимы друг от друга, т.е. каждый исход – это логистическая регрессия на два класса (либо есть тег, либо его нет), тогда вероятность наличия тега у примера запишется следующим образом (каждый тег/класс как и в многоклассовой логрегрессии имеет свой набор параметров):
# $$\large p\left(\text{tag}_k \mid \vec{x}\right) = \sigma\left(z_k\right) = \sigma\left(\sum_{i=1}^M w_{ki} x^i \right)$$
# - наличие каждого тега мы будем моделировать с помощью <a href="https://en.wikipedia.org/wiki/Bernoulli_distribution">распределения Бернулли</a>
#
# Ваше первое задание –  записать упрощенное выражение логарифма правдоподобия примера с признаками $\vec{x}$. Как правило, многие алгоритмы оптимизации имеют интерфейс для минимизации функции, мы последуем этой же традиции, и домножим полученное выражение на $-1$, а во второй части выведем формулы для минимизации полученного выражения.

# %% [markdown]
# <font color="red">Варианты ответа:</font>
# 1. $\large -\mathcal{L} = -\sum_{i=1}^M y_i \log \sigma\left(z_i\right) + \left(1 - y_i\right) \log \left(1 - \sigma\left(z_i\right)\right)$
# 2. $\large -\mathcal{L} = -\sum_{i=1}^K y_i \log \sigma\left(z_i\right) + \left(1 - y_i\right) \log \left(1 - \sigma\left(z_i\right)\right)$
# 3. $\large -\mathcal{L} = -\sum_{i=1}^K z_i \log \sigma\left(y_i\right) + \left(1 - z_i\right) \log \left(1 - \sigma\left(y_i\right)\right)$
# 4. $\large -\mathcal{L} = -\sum_{i=1}^M z_i \log \sigma\left(y_i\right) + \left(1 - z_i\right) \log \left(1 - \sigma\left(y_i\right)\right)$

# %% [markdown]
# ## 2. Вывод формулы обновления весов
#
# В качестве второго задания вам предоставляется возможность вывести формулу градиента для $-\mathcal{L}$.

# %% [markdown]
# <font color="red">Варианты ответа:</font>:
# 1. $\large -\frac{\partial \mathcal{L}}{\partial w_{km}} = -x_m \left(\sigma\left(z_k\right) - y_k\right)$
# 2. $\large -\frac{\partial \mathcal{L}}{\partial w_{km}} = -x_m \left(y_k - \sigma\left(z_k\right)\right)$
# 3. $\large -\frac{\partial \mathcal{L}}{\partial w_{km}} = \left(\sigma\left(z_k\right)x_m - y_k\right)$
# 4. $\large -\frac{\partial \mathcal{L}}{\partial w_{km}} = \left(y_k - \sigma\left(z_k\right)x_m\right)$

# %% [markdown]
# ## 3. Имплементация базовой модели
#
# Вам предлагается каркас класса модели, разберите его внимательно, обращайте внимание на комментарии. Затем заполните пропуски, запустите полученную модель и ответьте на проверочный вопрос.
#
# Как вы могли уже заметить, при обновлении веса $w_{km}$ используется значение признака $x_m$, который равен $0$ если слова с индексом $m$ нет в предложении, и больше нуля, если такое слово есть. Соответственно, при вычислении линейной комбинации $z$ весов модели и признаков примера необходимо учитывать только ненулевые признаки объекта.
#
# Подсказка:
# - если реализовывать вычисление сигмоида так же, как в формуле, то при большом отрицательном значении $z$ вычисление $e^{-z}$ превратится в очень большое число, которое вылетит за допустимые пределы
# - в то же время $e^{-z}$ от большого положительного $z$ будет нулем
# - воспользуйтесь свойствами функции $\sigma$ для того, чтобы пофиксить эту ошибку

# %%
np.exp(700)
# Out:
# 1.0142320547350045e+304

# %%
def sigmoid(x):
    if x > 300:
        return 1
    if x < -80:
        return 0

    return 1 / (1 + np.exp(-x))

# %%
def safe_log(x, low_x_guard):
    return np.log(max(x, low_x_guard))

# %%
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags_top : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16):
        
        self._loss = []
        n = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    z = self._b[tag]
   
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                        z += self._w[tag][self._vocab[word]] 
    
                    # вычисляем вероятность наличия тега
                    sigma = sigmoid(z)
    
                    
                    # обновляем значение функции потерь для текущего примера
                    sample_loss -= y * safe_log(sigma, tolerance) + (1 - y) * safe_log(1 - sigma, tolerance)
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        dLdw = y - sigma

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:                        
                            self._w[tag][self._vocab[word]] -= -learning_rate*dLdw
                        self._b[tag] -= -learning_rate*dLdw
                    
                n += 1
                        
                self._loss.append(sample_loss)

# %%
# создадим эксемпляр модели и пройдемся по датасету
model = LogRegressor()
model.iterate_file()

# %% [markdown]
# Проверим, действительно ли значение отрицательного логарифмического правдоподобия уменьшалось. Так как мы используем стохастический градентный спуск, не стоит ожидать плавного падения функции ошибки. Мы воспользуемся скользящим средним с окном в 10 000 примеров, чтобы хоть как то сгладить график.

# %%
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
print('Mean of the loss function on the last 10k train samples: %0.2f' % np.mean(model._loss[-35000:-25000]))
# Out:
# Mean of the loss function on the last 10k train samples: 19.42

# %% [markdown]
# Вычислите среднее значение функции стоимости на последних 10 000 примеров тренировочного набора, к какому из значений ваш ответ ближе всего?
#
# <font color="red">Варианты ответа:</font>:
# 1. 17.54
# 2. 18.64
# 3. 19.74
# 4. 20.84

# %% [markdown]
# ## 4. Тестирование модели
#
# В базовой модели первые 100 000 строк используются для обучения, а оставшиеся – для тестирования. Как вы можете заметить, значение отрицательного логарифмического правдоподобия не очень информативно, хоть и позволяет сравнивать разные модели. В качестве четвертого задания вам необходимо модифицировать базовую модель таким образом, чтобы метод `iterate_file` возвращал значение _точности_ на тестовой части набора данных.
#
# Точность определим следующим образом:
# - считаем, что тег у вопроса присутствует, если спрогнозированная вероятность тега больше 0.9
# - точность одного примера расчитывается как [коэффициент Жаккара](https://ru.wikipedia.org/wiki/Коэффициент_Жаккара) между множеством настоящих тегов и предсказанных моделью
#   - например, если у примера настоящие теги ['html', 'jquery'], а по версии модели ['ios', 'html', 'java'], то коэффициент Жаккара будет равен |['html', 'jquery'] $\cap$ ['ios', 'html', 'java']| / |['html', 'jquery'] $\cup$ ['ios', 'html', 'java']| = |['html']| / |['jquery', 'ios', 'html', 'java']| = 1/4
# - метод `iterate_file` возвращает **среднюю** точность на тестовом наборе данных

# %%
# Обновите определение класса LogRegressor
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags_top : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16):
        
        self._loss = []
        n = 0
        precision_sum = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                predicted_tags = set()
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    z = self._b[tag]
   
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                        z += self._w[tag][self._vocab[word]] 
    
                    # вычисляем вероятность наличия тега
                    sigma = sigmoid(z)
    
                    
                    # обновляем значение функции потерь для текущего примера
                    sample_loss -= y * safe_log(sigma, tolerance) + (1 - y) * safe_log(1 - sigma, tolerance)
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        dLdw = y - sigma

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:                        
                            self._w[tag][self._vocab[word]] -= -learning_rate*dLdw
                        self._b[tag] -= -learning_rate*dLdw
                    else:
                        if sigma > 0.9:
                            predicted_tags.add(tag)
                    
                if n >= top_n_train:
                    precision = len(tags & predicted_tags) / len(tags | predicted_tags)
                    precision_sum += precision
                    
                n += 1
                        
                self._loss.append(sample_loss)

        mean_precision = precision_sum / (n - top_n_train)    
        return mean_precision

# %%
model = LogRegressor()
acc = model.iterate_file()
# выведем полученное значение с точностью до двух знаков
print('%0.2f' % acc)
# Out:
# 0.58

# %% [markdown]
# Ответьте на вопрос,  к какому значению ближе всего полученное значение точности?
# <font color="red">Варианты ответа:</font>:
# 1. 0.39
# 2. 0.49
# 3. 0.59
# 4. 0.69

# %% [markdown]
# ## 5. $L_2$-регуляризация
#
# В качестве пятого задания вам необходимо добавить в класс `LogRegressor` поддержку $L_2$-регуляризации. В методе `iterate_file` должен появиться параметр `lmbda=0.01` со значением по умолчанию. С учетом регуляризации новая функция стоимости примет вид:
#
# $$\large \begin{array}{rcl}
# L &=& -\mathcal{L} + \frac{\lambda}{2} R\left(W\right) \\
# &=& -\mathcal{L} + \frac{\lambda}{2} \sum_{k=1}^K\sum_{i=1}^M w_{ki}^2
# \end{array}$$
#
# Градиент первого члена суммы мы уже вывели, а для второго он имеет вид:
#
# $$\large \begin{array}{rcl}
# \frac{\partial}{\partial w_{ki}} \frac{\lambda}{2} R\left(W\right) &=& \lambda w_{ki}
# \end{array}$$
#
# Если мы на каждом примере будем делать честное обновление всех весов, то все очень замедлится, ведь нам придется на каждой итерации пробегать по всем словам словаря. В ущерб теоретической точности вы используем грязный трюк: мы будем регуляризаровать только те слова, которые присутствуют в текущем предложении. Не забывайте, что смещение не регуляризируется. `sample_loss` тоже должен остаться без изменений.

# %%
# Обновите определение класса LogRegressor
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags_top : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
        
    lmbda : float, default=0.01
        коэффициент L2 регуляризации
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16,
                     lmbda=0.01):
        
        self._loss = []
        n = 0
        precision_sum = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                predicted_tags = set()
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    z = self._b[tag]
   
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                        z += self._w[tag][self._vocab[word]] 
    
                    # вычисляем вероятность наличия тега
                    sigma = sigmoid(z)
    
                    
                    # обновляем значение функции потерь для текущего примера
                    sample_loss -= y * safe_log(sigma, tolerance) + (1 - y) * safe_log(1 - sigma, tolerance)
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        dLdw = y - sigma

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:          
                            dRdw = lmbda*self._w[tag][self._vocab[word]]
                            self._w[tag][self._vocab[word]] -= -learning_rate*(dLdw-dRdw)
                        self._b[tag] -= -learning_rate*dLdw
                    else:
                        if sigma > 0.9:
                            predicted_tags.add(tag)
                    
                if n >= top_n_train:
                    precision = len(tags & predicted_tags) / len(tags | predicted_tags)
                    precision_sum += precision
                    
                n += 1
                        
                self._loss.append(sample_loss)

        mean_precision = precision_sum / (n - top_n_train)    
        return mean_precision

# %%
model = LogRegressor()
acc = model.iterate_file()
print('%0.2f' % acc)
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());
# Out:
# 0.52
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Ответьте на вопрос, к какому значению ближе всего полученное значение точности?
# <font color="red">Варианты ответа:</font>:
# 1. 0.3
# 2. 0.35
# 3. 0.4
# 4. 0.52

# %% [markdown]
# ## 6. ElasticNet регуляризация, вывод
# Помимо $L_2$ регуляризации, часто используется $L_1$ регуляризация.
#
# $$\large \begin{array}{rcl}
# L &=& -\mathcal{L} + \frac{\lambda}{2} R\left(W\right) \\
# &=& -\mathcal{L} + \lambda \sum_{k=1}^K\sum_{i=1}^M \left|w_{ki}\right|
# \end{array}$$
#
# Если линейно объединить $L_1$ и $L_2$ регуляризацию, то полученный тип регуляризации называется ElasticNet:
#
# $$\large \begin{array}{rcl}
# L &=& -\mathcal{L} + \lambda R\left(W\right) \\
# &=& -\mathcal{L} + \lambda \left(\gamma \sum_{k=1}^K\sum_{i=1}^M w_{ki}^2 + \left(1 - \gamma\right) \sum_{k=1}^K\sum_{i=1}^M \left|w_{ki}\right| \right)
# \end{array}$$
# - где $\gamma \in \left[0, 1\right]$
#
# В качестве шестого вопроса вам предлагается вывести формулу градиента ElasticNet регуляризации (не учитывая $-\mathcal{L}$).
#
# <font color="red">Варианты ответа:</font>:
# 1. $\large \frac{\partial}{\partial w_{ki}} \lambda R\left(W\right) = \lambda \left(2 \gamma w_{ki} + \left(1 - \gamma\right) w_{ki}\right)$
# 2. $\large \frac{\partial}{\partial w_{ki}} \lambda R\left(W\right) = \lambda \left(2 \gamma \left|w_{ki}\right| + \left(1 - \gamma\right) \text{sign}\left(w_{ki}\right)\right)$
# 3. $\large \frac{\partial}{\partial w_{ki}} \lambda R\left(W\right) = \lambda \left(2 \gamma w_{ki} + \left(1 - \gamma\right) \text{sign}\left(w_{ki}\right)\right)$
# 4. $\large \frac{\partial}{\partial w_{ki}} \lambda R\left(W\right) = \lambda \left(\gamma w_{ki} + \left(1 - \gamma\right) \text{sign}\left(w_{ki}\right)\right)$

# %% [markdown]
# ## 7. ElasticNet регуляризация, имплементация
#
# В качестве седьмой задачи, вам предлается изменить класс `LogRegressor` таким образом, чтобы метод `iterate_file` принимал два параметра со значениями по умолчанию `lmbda=0.0002` и `gamma=0.1`. Сделайте один проход по датасету с включенной ElasticNet регуляризацией и заданными значениями по умолчанию и ответьте на вопрос.

# %%
# Обновите определение класса LogRegressor
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags_top : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
        
    lmbda : float, default=0.0002
        коэффициент ElasticNet регуляризации
        
    gamma : float, default=0.1
        вес квадротичной части в ElasticNet регуляризации
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16,
                     lmbda=0.0002,
                     gamma=0.1):
        
        self._loss = []
        n = 0
        precision_sum = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                predicted_tags = set()
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    z = self._b[tag]
   
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                        z += self._w[tag][self._vocab[word]] 
    
                    # вычисляем вероятность наличия тега
                    sigma = sigmoid(z)
    
                    
                    # обновляем значение функции потерь для текущего примера
                    sample_loss -= y * safe_log(sigma, tolerance) + (1 - y) * safe_log(1 - sigma, tolerance)
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        dLdw = y - sigma

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:     
                            w = self._w[tag][self._vocab[word]]
                            dRdw = lmbda*(2*gamma*w+(1-gamma)*np.sign(w))
                            self._w[tag][self._vocab[word]] -= -learning_rate*(dLdw-dRdw)
                        self._b[tag] -= -learning_rate*dLdw
                    else:
                        if sigma > 0.9:
                            predicted_tags.add(tag)
                    
                if n >= top_n_train:
                    precision = len(tags & predicted_tags) / len(tags | predicted_tags)
                    precision_sum += precision
                    
                n += 1
                        
                self._loss.append(sample_loss)

        mean_precision = precision_sum / (n - top_n_train)    
        return mean_precision

# %%
model = LogRegressor()
acc = model.iterate_file()
print('%0.2f' % acc)
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());
# Out:
# 0.56
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Ответьте на вопрос,  к какому значению ближе всего полученное значение точности:
# <font color="red">Варианты ответа:</font>
# 1. 0.59
# 2. 0.69
# 3. 0.79
# 4. 0.82

# %% [markdown]
# ## 8. Самые важные слова для тега
#
# Прелесть линейных моделей в том, что они легко интерпретируемы. Вам предлагается вычислить, какие слова вносят наибольший вклад в вероятность каждого из тегов. А затем ответьте на контрольный вопрос.

# %%
len(model._w)
# Out:
# 10

# %%
top_tags
# Out:
# {'android',
#  'c#',
#  'c++',
#  'html',
#  'ios',
#  'java',
#  'javascript',
#  'jquery',
#  'php',
#  'python'}

# %%
len(model._vocab)
# Out:
# 519290

# %%
top_w_count = 10
for tag in top_tags:
    s = tag + ": "
    indx_and_w = sorted(model._w[tag].items(), key=lambda x: -x[1])[:top_w_count]
    for iw in indx_and_w:
        for w, i in model._vocab.items():
            if i==iw[0]:
                s += w + ", "
    print(s[:-2])
# Out:
# jquery: jquery, ready, ajax, span, val, li, strong, sdf, td, href
# php: php, _post, echo, x5c, 125, gt, mysql, dial_code, amp, isset
# html: 3, br, html, lt, amp, span, nav, th, p, gt
# ios: ios, dylib, nsstring, nil, uiview, corefoundation, xcode, nslog, iphone, alloc
# java: println, spring, java, jsp, servlet, hibernate, 176, springframework, bean, org
# c++: c++, avrf, std, cout, cpp, const, boost, qt, trace, _defaultimage
# c#: writeline, linq, net, binding, usbuffer, ienumerable, foreach, eventargs, sender, xaml
# javascript: javascript, x20, 3, 125, x30, x44, x42, x36, js, getelementbyid
# android: android, 29691, imgsrv, 29297, art, activity, 0x0, 18870, ff, quot
# python: python, def, py, django, np, print, numpy, import, len, dataframe

# %% [markdown]
# Для многих тегов наличие самого тега в предложении является важным сигналом, у многих сам тег является самым сильным сигналом, что неудивительно. Для каких из тегов само название тега не входит в топ-5 самых важных?
#
# <font color="red">Варианты ответа:</font>
# 1. java, c#
# 2. php, javascript
# 3. html, jquery
# 4. ios, android

# %% [markdown]
# ## 9. Сокращаем размер словаря
# Сейчас количество слов в словаре около 90 000, если бы это была выборка из 10 миллионов вопросов с сайта StackOverflow, то размер словаря был бы миллионов 10. Регуляризировать модель можно не только изящно математически, но и топорно, например, ограничить размер словаря. Вам предоставляется возможность внести следующие изменения в класс `LogRegressor`:
# - добавить в метод `iterate_file` еще один аргумент со значением по умолчанию `update_vocab=True`
# - при `update_vocab=True` разрешать добавлять слова в словарь в режиме обучения
# - при `update_vocab=False` игнорировать слова не из словаря
# - добавить в класс метод `filter_vocab(n=10000)`, который оставит в словаре только топ-n самых популярных слов

# %%
# Обновите определение класса LogRegressor
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags_top : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # {word_id: count}
        self._vocabcounts = defaultdict(int)
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
        
    lmbda : float, default=0.0002
        коэффициент ElasticNet регуляризации
        
    gamma : float, default=0.1
        вес квадротичной части в ElasticNet регуляризации
        
    update_vocab : bool, default=True
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16,
                     lmbda=0.0002,
                     gamma=0.1,
                     update_vocab=True):
        
        self._loss = []
        n = 0
        precision_sum = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                predicted_tags = set()
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    z = self._b[tag]
   
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if update_vocab:
                            if word not in self._vocab:
                                self._vocab[word] = len(self._vocab)
                            self._vocabcounts[self._vocab[word]] += 1
                        else:
                            continue
                        z += self._w[tag][self._vocab[word]] 
    
                    # вычисляем вероятность наличия тега
                    sigma = sigmoid(z)
    
                    
                    # обновляем значение функции потерь для текущего примера
                    sample_loss -= y * safe_log(sigma, tolerance) + (1 - y) * safe_log(1 - sigma, tolerance)
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        dLdw = y - sigma

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:   
                            if word not in self._vocab:
                                continue
                            w = self._w[tag][self._vocab[word]]
                            dRdw = lmbda*(2*gamma*w+(1-gamma)*np.sign(w))
                            self._w[tag][self._vocab[word]] -= -learning_rate*(dLdw-dRdw)
                        self._b[tag] -= -learning_rate*dLdw
                    else:
                        if sigma > 0.9:
                            predicted_tags.add(tag)
                    
                if n >= top_n_train:
                    precision = len(tags & predicted_tags) / len(tags | predicted_tags)
                    precision_sum += precision
                    
                n += 1
                        
                self._loss.append(sample_loss)

        mean_precision = precision_sum / (n - top_n_train)    
        return mean_precision
    
    """
    Оставляет в словаре n самых популярных слов
    """
    def filter_vocab(self, n=10000):
        top_word_ids = sorted(self._vocabcounts.items(), key=lambda x: -x[1])[:n]
        
        new_vocab = {}
        for word, i in model._vocab.items():
            for top_id, top_count in top_word_ids:
                if i == top_id:
                    new_vocab[word] = i 
                
        self._vocab = new_vocab

# %%
model = LogRegressor()
acc = model.iterate_file(update_vocab=True)
print('%0.2f' % acc)
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());
# Out:
# 0.56
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# оставим только топ 10 000 слов
model.filter_vocab(n=10000)

# %%
model._vocab
# Out:
# {'': 83,
#  'file': 624,
#  'sh': 4998,
#  'readystate': 6500,
#  'with': 267,
#  'bit': 3440,
#  'phones': 10782,
#  'version_codes': 11611,
#  'intranet': 7905,
#  'bug': 3174,
#  'searchterm': 42768,
#  'pyw': 103989,
#  'scheduling': 4467,
#  'hear': 24398,
#  'qt': 6162,
#  'tcpclient': 44074,
#  'voice': 14924,
#  'anybody': 1776,
#  'mediatype': 15219,
#  'highlighted': 13792,
#  'text1': 4218,
#  'nullable': 12004,
#  'feels': 5094,
#  'consistently': 30079,
#  'seat': 10658,
#  'fake': 11285,
#  'usage': 3909,
#  'header': 2197,
#  'terminates': 1608,
#  'out': 415,
#  'retrieve': 3334,
#  'useragent': 873,
#  'cflags': 7648,
#  'processstartinfo': 14797,
#  'desired': 4850,
#  'xhttp': 6995,
#  'jsonstring': 35621,
#  'getresponsestream': 49690,
#  'archive': 579,
#  '989': 9913,
#  'regex': 4471,
#  'copy': 1650,
#  'surely': 1789,
#  'netbeans': 3697,
#  'eventdispatchthread': 7445,
#  'keywords': 3912,
#  '42': 8848,
#  'jbossweb': 70434,
#  'forbidden': 15197,
#  'gestures': 29988,
#  'firstname': 375,
#  'viewpager': 12372,
#  'nonnull': 11419,
#  'xib': 4122,
#  'handlerequest': 62369,
#  'mymodule': 37397,
#  'picked': 2784,
#  'aspnet': 31948,
#  'afnetworking': 24967,
#  'mode_private': 1149,
#  'skeleton': 2280,
#  'combined': 4210,
#  'ado': 4737,
#  'hbm': 12597,
#  'parameters': 2374,
#  'following': 581,
#  'zindex': 33312,
#  'leads': 27261,
#  'physics': 11870,
#  'generate': 431,
#  'textalignment': 12970,
#  'selenium': 1277,
#  '101': 3844,
#  'singleline': 22020,
#  'leak': 10880,
#  'began': 9174,
#  'lhs': 18927,
#  'scaled': 9699,
#  'l2': 15339,
#  'behaves': 1785,
#  '0a': 16687,
#  '21': 226,
#  'invoices': 47440,
#  'qstring': 7124,
#  'buildtoolsversion': 9955,
#  'tobytearray': 5128,
#  'showed': 2267,
#  'america': 25179,
#  'environ': 31712,
#  'arm': 5540,
#  'pdo': 4698,
#  'xy': 9923,
#  'product_name': 13038,
#  'spread': 26265,
#  'timestamps': 12882,
#  'refs': 27544,
#  'computing': 2053,
#  'appconfig': 7209,
#  'migrations': 27609,
#  'hub': 14648,
#  'laptop': 6147,
#  'classpath': 4767,
#  'inventory': 12209,
#  'indicate': 4586,
#  'checkmark': 46964,
#  '00000000': 26992,
#  'recorder': 2507,
#  'basedir': 49582,
#  'fasterxml': 28554,
#  'stub': 2527,
#  'beta': 14644,
#  'derby': 6691,
#  'bankaccount': 85215,
#  'finding': 4429,
#  'duplicated': 8842,
#  'uialertview': 16189,
#  'xxxxxx': 6986,
#  'plunker': 3106,
#  'dbo': 1887,
#  'subset': 2833,
#  'pos': 10437,
#  '18870': 512225,
#  'provided': 5727,
#  'installing': 6628,
#  'publish': 5762,
#  'zipfile': 9603,
#  'asax': 36116,
#  'param_str': 57631,
#  'jioendpoint': 49944,
#  'volley': 29939,
#  '505': 19510,
#  'october': 30095,
#  'synchronous': 3577,
#  'update': 1904,
#  'expandablelistview': 26484,
#  'in_array': 5428,
#  'isnan': 36104,
#  'expired': 15287,
#  'exe': 2195,
#  'postback': 3585,
#  'interpreter': 22842,
#  '2': 437,
#  'replacement': 968,
#  'mybutton': 9549,
#  'detection': 6508,
#  'might': 238,
#  'crypt': 48540,
#  'database': 810,
#  'getitem': 8447,
#  'value3': 22549,
#  'manufacturerid': 69468,
#  'stamp': 13272,
#  'joda': 96536,
#  'subclass': 6054,
#  'animatewithduration': 10064,
#  'generationtype': 5925,
#  'onmeasure': 22024,
#  'pem': 14221,
#  '__thiscall': 23869,
#  'combobox': 1636,
#  'multiline': 14053,
#  'insights': 7510,
#  'tables': 5331,
#  'board': 8982,
#  'variable': 2620,
#  'detail': 2099,
#  'anything': 360,
#  'keyframes': 56717,
#  'continue': 1040,
#  'fit': 2671,
#  'traditional': 8633,
#  'intend': 18857,
#  '256': 21940,
#  'gps': 1671,
#  'mysql_fetch_assoc': 27588,
#  'server': 105,
#  'finished': 3922,
#  '2c': 29549,
#  'num2': 15688,
#  'number2': 8037,
#  'arial': 12091,
#  'downloaded': 103,
#  'respect': 4798,
#  'cert': 21710,
#  'sites': 5696,
#  'simulator': 6160,
#  'center': 1051,
#  '1e': 10419,
#  'bitmapfactory': 1768,
#  'firing': 25,
#  'cover': 1370,
#  'getusername': 68638,
#  'ui': 3119,
#  'angularjs': 4329,
#  'php_self': 4707,
#  'copied': 7322,
#  'x41': 275758,
#  'warning': 511,
#  'rec': 4895,
#  'do': 107,
#  'jit': 24626,
#  'exampleproguard': 243578,
#  'validation': 5673,
#  'hyperlink': 17009,
#  'rw': 28112,
#  'significant': 14879,
#  'alarmmanager': 53266,
#  'greetings': 19049,
#  'tricky': 1265,
#  'binded': 26040,
#  'restriction': 11460,
#  'pageid': 14739,
#  'foobar': 12866,
#  'columnname': 11452,
#  'ordering': 8147,
#  'selection': 2010,
#  'invalidate': 1078,
#  'hasclass': 3088,
#  'shut': 7926,
#  'cpp': 4847,
#  'istream': 21062,
#  'spider': 2211,
#  'signalr': 46455,
#  'pastebin': 5305,
#  'hide': 3030,
#  'b3': 25234,
#  '1300': 18005,
#  'myself': 1991,
#  'ehcache': 12577,
#  'mvn': 21542,
#  '50': 1518,
#  'quartz': 39768,
#  'confusion': 15102,
#  'onmouseover': 18999,
#  'addgap': 75185,
#  'timer': 1059,
#  '666': 13782,
#  'technical': 8143,
#  'grades': 4237,
#  'arrayindexoutofboundsexception': 7422,
#  'egl': 46937,
#  'instrumentation': 3226,
#  'uibutton': 4119,
#  'prod': 19571,
#  'pygame': 10085,
#  'manipulate': 13047,
#  'fc': 7419,
#  'onto': 476,
#  'locals': 28953,
#  'valueof': 3762,
#  't2': 9856,
#  'decrypted': 18452,
#  'june': 10327,
#  'toolkit': 2032,
#  'beer': 29928,
#  'least': 363,
#  'threw': 9033,
#  's1': 12668,
#  'xwork2': 145880,
#  'manytomany': 62364,
#  'backbone': 6659,
#  'chinese': 16408,
#  'bd': 45355,
#  'jlist': 28237,
#  'require': 2190,
#  'dbh': 7580,
#  'albums': 17219,
#  'capturing': 17040,
#  'userinfo': 1070,
#  'jsx': 917,
#  'uitableviewcontroller': 8853,
#  'storyboard': 8857,
#  'compilesdkversion': 9954,
#  'ie': 560,
#  'isn': 2474,
#  'games': 5113,
#  '116': 15152,
#  'somehow': 3814,
#  'fired': 3635,
#  'cost': 4520,
#  'yellow': 2316,
#  '_': 2768,
#  'parsing': 4154,
#  'x0': 19327,
#  'mdrawertoggle': 33100,
#  'stdlib': 27629,
#  'action_settings': 8444,
#  'getextras': 6612,
#  'divider': 8459,
#  'blackcolor': 11817,
#  'contour': 1304,
#  'isbn': 51919,
#  'applying': 22603,
#  'pc': 1891,
#  'ga': 12250,
#  '70px': 6422,
#  'theres': 22634,
#  'operate': 19229,
#  'goals': 22963,
#  '580': 33281,
#  'io': 3230,
#  'cgrectmake': 1389,
#  'arduino': 10081,
#  'webcontainer': 109268,
#  'usg': 178219,
#  'verb': 14795,
#  'getuser': 8069,
#  'liked': 30742,
#  'homecontroller': 13262,
#  'despite': 7919,
#  'optional': 1525,
#  'xmlnode': 17272,
#  'te': 43765,
#  'progressdialog': 6166,
#  'within': 2745,
#  'merging': 29617,
#  '62': 13192,
#  'effects': 10109,
#  'chat': 7583,
#  'xmlreader': 26047,
#  'webdriver': 21396,
#  'part': 448,
#  'division': 4787,
#  'generic': 2790,
#  'silver': 28667,
#  'theta': 48238,
#  'mic': 9714,
#  'insert': 1873,
#  'svc': 26149,
#  'exits': 14808,
#  'continues': 11877,
#  'rates': 5554,
#  '184': 16396,
#  'serializers': 136185,
#  'elem': 3133,
#  'elit': 19269,
#  'str': 1743,
#  'cloud': 13043,
#  'visualization': 30443,
#  'way': 206,
#  'involved': 7465,
#  'param': 4784,
#  'catalog': 4060,
#  'lastname': 8000,
#  'added': 180,
#  'mdbhelper': 12129,
#  'coffee': 40904,
#  'boxlayout': 8238,
#  'sphere': 31651,
#  'namespaces': 18930,
#  'essentially': 8629,
#  'w64': 105299,
#  'delete': 734,
#  '69': 9622,
#  'getfilename': 10597,
#  'magna': 22180,
#  'alternative': 3152,
#  'layout_weight': 3321,
#  'intercept': 5385,
#  'package': 1655,
#  '220': 7454,
#  'log4net': 91967,
#  'y++': 14746,
#  'onload': 9205,
#  'existing': 764,
#  'salary': 5826,
#  'dlg': 15890,
#  'chr': 6682,
#  'camel': 28007,
#  'cell2': 11388,
#  'recommended': 2533,
#  'cells': 8855,
#  'face': 5706,
#  'ontouchevent': 18120,
#  'nltk': 7593,
#  'exemple': 9251,
#  'recursively': 12507,
#  'march': 10326,
#  'communicate': 1172,
#  'suggest': 659,
#  'flags': 1526,
#  'executions': 24582,
#  'loses': 8546,
#  'wchar_t': 10753,
#  'delegatingconstructoraccessorimpl': 18665,
#  'jtextarea': 17673,
#  'p0': 14526,
#  'og': 25786,
#  'was': 332,
#  'rinflate': 34175,
#  'repeat': 4342,
#  'icon': 516,
#  'collect': 14878,
#  'gettime': 8725,
#  'minifyenabled': 25003,
#  'mime': 14357,
#  'shows': 636,
#  'paddingtop': 6829,
#  'data_list': 134851,
#  'paddingright': 6828,
#  'skip': 11370,
#  'mysql_connect': 3456,
#  'dict': 7309,
#  '5': 227,
#  'spaces': 1984,
#  'expression': 1735,
#  'accordingly': 2359,
#  'contrib': 5642,
#  'motionevent': 13390,
#  'pop': 7882,
#  'prices': 19150,
#  'collection': 316,
#  'commandtext': 4069,
#  'onpostexecute': 1847,
#  '138': 7979,
#  'mysqli_query': 5898,
#  'east': 8194,
#  'nsindexpath': 6078,
#  'numero': 44766,
#  'ps': 1869,
#  'circles': 6550,
#  'streams': 2849,
#  'vis': 27820,
#  'xmpp': 8063,
#  'steve': 27618,
#  'iso': 7791,
#  'getmap': 3014,
#  'mustache': 51110,
#  'item2': 3829,
#  'populates': 5318,
#  'unrecognized': 18504,
#  'spirit': 23517,
#  '135': 10177,
#  'fields': 94,
#  'getline': 7226,
#  'bigdecimal': 16807,
#  'textwatcher': 66229,
#  'school': 4550,
#  'advantages': 39631,
#  'those': 1209,
#  'setid': 12199,
#  'display_name': 3345,
#  'trying': 256,
#  'maven': 2026,
#  'taken': 1759,
#  'xx': 3821,
#  'wpdb': 33856,
#  'nsfetchedresultscontroller': 15712,
#  'temp1': 1119,
#  'organize': 14365,
#  'servicestack': 26874,
#  'triggering': 18315,
#  'imageadapter': 49209,
#  'mainloop': 11244,
#  'backup': 6559,
#  'constantly': 8551,
#  'pagex': 21906,
#  'makes': 780,
#  'outgoing': 26377,
#  'responsestring': 3238,
#  'splashscreen': 18494,
#  'yourself': 45229,
#  'operator+': 6280,
#  'pick': 3144,
#  'servername': 1878,
#  'pin': 8858,
#  'wherever': 6625,
#  'james': 18283,
#  'newuser': 7024,
#  'loads': 4369,
#  '105': 13916,
#  'given': 1164,
#  '558': 18620,
#  'seekbar': 34126,
#  'doctrine': 11588,
#  'scrolled': 7901,
#  'notifydatasetchanged': 30263,
#  'submitform': 23333,
#  'aspectj': 39025,
#  'scrollviewer': 41870,
#  'minus': 9407,
#  'fits': 9485,
#  '238': 12089,
#  'col3': 1930,
#  'setdisplayhomeasupenabled': 26551,
#  'webrequest': 7546,
#  'backwards': 13389,
#  'posx': 1379,
#  'protection': 22771,
#  'setjavascriptenabled': 9799,
#  'dximagetransform': 38883,
#  'app_id': 13807,
#  'handlelaunchactivity': 3195,
#  'chance': 14187,
#  'collections': 3280,
#  'immutable': 9057,
#  'wins': 8885,
#  '284': 6816,
#  'line2': 21651,
#  'resid': 22472,
#  'giving': 2317,
#  'photos': 21784,
#  'apk': 3000,
#  'yield': 6436,
#  'googled': 15458,
#  'crashes': 4193,
#  'run': 648,
#  'ab': 6120,
#  'entitymanager': 18523,
#  'r0': 26993,
#  '644': 14344,
#  '6s': 26620,
#  '114': 9604,
#  'contenteditable': 14717,
#  'clear': 548,
#  'weather': 1656,
#  'mainbundle': 12995,
#  'idle': 17133,
#  'fecha': 11374,
#  'sheet': 10503,
#  '299': 8468,
#  'releases': 9733,
#  '_e': 55159,
#  'deg': 9326,
#  'thumbs': 56334,
#  'declarations': 23696,
#  'tbody': 6411,
#  'notebook': 21257,
#  'bw': 22989,
#  'stroke': 2129,
#  'money': 2293,
#  'sqlconnection': 4057,
#  'anon': 13917,
#  'pre': 3613,
#  'classnotfoundexception': 10030,
#  'average': 4251,
#  'personal': 14712,
#  'gd': 19446,
#  'unfortunately': 3610,
#  '373': 58369,
#  'ie8': 10290,
#  'junit4': 40999,
#  'isolate': 19156,
#  'truly': 19217,
#  '25px': 7860,
#  'file_put_contents': 35076,
#  'cfg': 6701,
#  'isotope': 16064,
#  'stmt': 4694,
#  'subjects': 4389,
#  'alright': 14015,
#  'previously': 7321,
#  'onreceive': 6608,
#  'percentage': 4514,
#  'hh': 2684,
#  'aug': 17398,
#  'comparison': 9446,
#  'ma': 7768,
#  'scaling': 7355,
#  'echoing': 47022,
#  '+str': 6501,
#  'remote': 5659,
#  '189': 7450,
#  'detatch': 438848,
#  'm1': 60904,
#  'actionevent': 8247,
#  'route': 2239,
#  'kit': 29542,
#  'searchtext': 46167,
#  'called': 1082,
#  'description': 1134,
#  'me': 379,
#  'detect': 2757,
#  'a3': 38114,
#  'bought': 15226,
#  'hell': 25711,
#  'remark': 15068,
#  'typical': 5108,
#  'joincolumn': 7375,
#  'integrity': 31550,
#  'warn': 6124,
#  'secondly': 16962,
#  'stylesheets': 26847,
#  'glyph': 135347,
#  'itertools': 11858,
#  'webcam': 36717,
#  'attempting': 1182,
#  'along': 1752,
#  'collected': 18921,
#  '354': 37608,
#  'plaf': 26722,
#  'foo': 3281,
#  'setuptools': 40078,
#  'getfile': 7225,
#  'installs': 30123,
#  'bluetooth': 1712,
#  'injector': 29015,
#  'filetree': 12603,
#  'getlatitude': 4162,
#  'technologies': 22922,
#  'drawer': 5603,
#  'button': 513,
#  'layout_gravity': 6841,
#  'fname': 3461,
#  'facet': 4579,
#  'getsharedpreferences': 1147,
#  'gdata': 28672,
#  'uiwindow': 11575,
#  'l1': 12409,
#  'screensize': 60248,
#  'kinda': 1577,
#  'hotel': 25652,
#  'isauthenticated': 13165,
#  'plus': 10104,
#  'ph': 7850,
#  'li': 2468,
#  'didselectrowatindexpath': 12936,
#  '557': 18001,
#  'lastindexof': 14138,
#  '502': 62419,
#  'scores': 32071,
#  'preparestatement': 7741,
#  '356': 17998,
#  'backing': 44213,
#  'eol': 51742,
#  'lead': 4762,
#  'inheriting': 46710,
#  'foreach': 393,
#  'gold': 21946,
#  'tag_id': 37568,
#  '100000': 10989,
#  'containerbase': 17980,
#  'dos': 20728,
#  '268': 34623,
#  'perform': 1106,
#  'tid': 9081,
#  'color': 3096,
#  'excel': 5387,
#  'msg': 2334,
#  '349': 10250,
#  'ec2': 4999,
#  'hack': 11222,
#  'animals': 9493,
#  'address1': 7690,
#  'performed': 14127,
#  'submitbutton': 5798,
#  'point': 473,
#  'transition': 3098,
#  'tip': 758,
#  'smtpclient': 35252,
#  'market': 4658,
#  'templating': 14382,
#  'visual': 2021,
#  'pyd': 3680,
#  'amazon': 4994,
#  'listeners': 11252,
#  'divide': 8046,
#  'xmlhttprequest': 4537,
#  'pixel': 10360,
#  'jni': 9948,
#  'viewgroup': 122,
#  'disc': 17735,
#  'met': 6693,
#  'tensorflow': 21697,
#  'pending': 4391,
#  'feel': 1347,
#  'visits': 14890,
#  '__str__': 12253,
#  'cuda': 2031,
#  'appends': 9917,
#  'exist': 1506,
#  'aid': 8736,
#  'subtype': 18839,
#  'bundle': 1663,
#  'general': 4206,
#  'getattr': 14260,
#  'describe': 3815,
#  'listings': 20307,
#  'occurred': 741,
#  'errorhandler': 36093,
#  'myid': 1954,
#  'targetframework': 34931,
#  'nickname': 46743,
#  'deploying': 7260,
#  '2001': 7474,
#  'dsf': 150028,
#  'sf': 12636,
#  'compares': 20941,
#  'tz': 15708,
#  'sklearn': 5150,
#  'functioning': 17514,
#  'arrange': 35664,
#  'september': 30094,
#  'square': 6623,
#  '401': 8296,
#  'fieldset': 11086,
#  '1s': 3099,
#  'dbcp': 7491,
#  'studentid': 33704,
#  'sockets': 14925,
#  '219': 17991,
#  'affect': 9701,
#  'phtml': 17852,
#  'coord': 50061,
#  'knows': 1701,
#  'control': 2437,
#  'managedobjectcontext': 15728,
#  'properly': 1649,
#  'wc': 4909,
#  'sim': 49079,
#  '345': 6068,
#  'mydatabase': 73823,
#  'conf': 9026,
#  'c0': 50476,
#  'deviceid': 74436,
#  'dataitem': 3572,
#  'nameerror': 12729,
#  'usertype': 31348,
#  'searching': 1467,
#  'spec': 11626,
#  'pp': 4862,
#  'notifications': 4277,
#  'game': 2282,
#  'strings': 4588,
#  'indicator': 2638,
#  'selectedvalue': 11814,
#  'getintent': 26580,
#  'unresolved': 11407,
#  'onclicklistener': 1693,
#  'phpmyadmin': 23532,
#  'represents': 1522,
#  'shop': 2947,
#  'nonatomic': 6060,
#  'nil': 1060,
#  'mapview': 3001,
#  'degree': 7941,
#  'half': 6148,
#  'messages': 2335,
#  '242': 18611,
#  'uniform': 15519,
#  'as': 40,
#  'onnext': 116851,
#  'didnt': 14320,
#  'push_back': 6272,
#  'companyid': 19291,
#  'difficulty': 3356,
#  'include_once': 10930,
#  'succesfully': 7541,
#  'nslayoutconstraint': 13121,
#  'input2': 24238,
#  'qdebug': 28003,
#  'parents': 10796,
#  'soapserializationenvelope': 4086,
#  'focused': 2522,
#  'getoutputstream': 709,
#  'completion': 8570,
#  'fmt': 10451,
#  'fusion': 47021,
#  'globals': 16461,
#  'asd': 6412,
#  'pink': 16021,
#  'nom': 27593,
#  'x36': 123854,
#  'friend': 5096,
#  'bid': 2166,
#  'mactivity': 125179,
#  'renderscript': 7010,
#  'touches': 7532,
#  'jwt': 36387,
#  'tall': 7900,
#  'flag_activity_clear_top': 20791,
#  '423': 21811,
#  'groupid': 21429,
#  'numeric': 25546,
#  'i': 0,
#  '_this': 84940,
#  'bound': 12264,
#  'disabling': 9550,
#  'movement': 36718,
#  'w3c': 2860,
#  'borderthickness': 3380,
#  'amount': 5573,
#  'killing': 12326,
#  'texture2d': 15553,
#  'pointing': 8630,
#  'getcontext': 2086,
#  'headertext': 25044,
#  'delivered': 28320,
#  'xhtml': 2799,
#  'sqrt': 1123,
#  'first_name': 23230,
#  'base64': 8675,
#  'industry': 24721,
#  'australia': 67346,
#  'dofilter': 9090,
#  'commenting': 9989,
#  'modified': 2778,
#  'sqlquery': 15836,
#  'escape': 12278,
#  'compute': 5138,
#  '126': 42592,
#  'xstream': 35617,
#  'sid': 9217,
#  'carry': 19634,
#  'char_traits': 19617,
#  'dat': 26611,
#  'uipickerview': 12418,
#  'problem': 366,
#  'mytext': 5736,
#  'a2': 18934,
#  'kw': 44261,
#  'standarduserdefaults': 19007,
#  'exit_on_close': 14688,
#  'technically': 2803,
#  'newsletter': 11079,
#  '442': 59931,
#  'aws': 6116,
#  'ontouchlistener': 13398,
#  'mylogger': 77169,
#  'nio': 13905,
#  'pic': 7702,
#  'releasing': 17230,
#  'gridbaglayout': 28194,
#  'pane': 4211,
#  'opt': 7001,
#  'karma': 45241,
#  'that': 8,
#  'tp': 22773,
#  'avrf': 112861,
#  'simpleadapter': 6215,
#  'integrate': 14336,
#  'charts': 9484,
#  'cheers': 849,
#  '15000': 1601,
#  'parentheses': 21291,
#  'myview': 39018,
#  'outer': 7141,
#  'benchmark': 25831,
#  'stackoverflow': 1466,
#  'getsource': 28217,
#  'withrowanimation': 18950,
#  'page1': 13790,
#  'drawer_layout': 8427,
#  'confirmation': 7660,
#  'someclass': 7918,
#  '3c': 35285,
#  'applied': 1865,
#  'thumbnails': 101,
#  'select2': 16106,
#  'place': 1056,
#  '777': 967,
#  'rule': 5672,
#  'render': 924,
#  'createstatement': 8743,
#  'r2': 7140,
#  'jsonobj': 6203,
#  'date': 1717,
#  'amazonaws': 48578,
#  'scanner': 4507,
#  'webapi': 8661,
#  'reject': 8984,
#  'behave': 5730,
#  'disposing': 92645,
#  'nsjsonserialization': 9543,
#  'positive': 4196,
#  'ai': 5492,
#  'longer': 5425,
#  'statusbar': 11569,
#  '205': 10042,
#  'melegram': 512226,
#  'allowfullscreen': 21472,
#  'priority': 1136,
#  'sdks': 14337,
#  'orient': 31574,
#  'v0': 983,
#  'lengths': 1523,
#  'baz': 33766,
#  'qt5': 44990,
#  'datatable': 4806,
#  'spawn': 16305,
#  'business': 3509,
#  'standardcontextvalve': 49934,
#  'unsupportedencodingexception': 6197,
#  'arises': 1764,
#  'panels': 4208,
#  'appear': 1738,
#  'methodandargscaller': 2974,
#  'simultaneously': 3920,
#  'mdata': 18888,
#  'varchar': 3452,
#  'wildcard': 7655,
#  'stocks': 24322,
#  'until': 1502,
#  'maintenance': 42451,
#  'unhandled': 2584,
#  'unchanged': 34808,
#  'mouse': 1979,
#  'pe': 6169,
#  'stumped': 15116,
#  'firefox': 531,
#  'ready': 1570,
#  'p12': 78386,
#  'forcontrolevents': 12960,
#  'html4': 30790,
#  'startswith': 15038,
#  'objectforkey': 6087,
#  'strokecolor': 10331,
#  'reorder': 10800,
#  'glyphicon': 28391,
#  'q3': 56381,
#  'virtualenvs': 51061,
#  'coded': 7158,
#  'fillrect': 2108,
#  'hang': 10779,
#  'trust': 9003,
#  'bst': 25183,
#  'reload': 195,
#  'absolutely': 9150,
#  'vtk': 133333,
#  'utility': 4602,
#  'generation': 12281,
#  'touch': 9473,
#  '306': 9202,
#  'tabbar': 13555,
#  'alphabets': 36559,
#  'environmental': 30355,
#  '10px': 2660,
#  'assemblies': 34932,
#  'contenttype': 545,
#  'getname': 2710,
#  'caching': 8601,
#  'grabbing': 28763,
#  'guaranteed': 317,
#  'act': 9292,
#  'deferred': 16004,
#  'much': 355,
#  'kendo': 3617,
#  'msgs': 6615,
#  '295': 26709,
#  'bird': 33086,
#  'click': 1569,
#  'name1': 12735,
#  'glass': 12931,
#  'pixels': 10358,
#  'inputstream': 676,
#  'jetbrains': 36255,
#  'switched': 1711,
#  'xcode': 4118,
#  'equalto': 15019,
#  'curl_exec': 3831,
#  'presentation': 14410,
#  'dev': 9149,
#  'occasionally': 7584,
#  'ticket': 1269,
#  'arg1': 4306,
#  'wheel': 25220,
#  'straight': 1866,
#  'mobile': 2940,
#  'instantiate': 7396,
#  'fileinput': 24066,
#  '170': 12260,
#  'o': 2091,
#  'ljava': 4101,
#  'marker': 17474,
#  '227': 3860,
#  'navigate': 2626,
#  'classes': 901,
#  'fr': 3545,
#  'subtitle': 17394,
#  'resources': 3187,
#  'which': 259,
#  'thevalue': 73033,
#  'yjavac': 512905,
#  'explains': 970,
#  'v3': 8786,
#  'north': 8191,
#  'remaining': 21313,
#  'println': 2519,
#  'terminating': 27529,
#  'sock_stream': 21865,
#  'constants': 8122,
#  'setcenter': 48175,
#  'documents': 1474,
#  'fades': 12297,
#  'starting': 1716,
#  'localization': 25620,
#  'j2ee': 2034,
#  'meant': 11684,
#  'guzzle': 43023,
#  '515': 2972,
#  'index++': 18991,
#  'xslt': 20343,
#  'e4': 101150,
#  'evaluating': 19929,
#  'year': 1174,
#  'install': 3036,
#  'interpret': 10907,
#  'columndefinition': 3386,
#  'altogether': 10897,
#  'backgrounds': 7903,
#  ...}

# %%
# сделаем еще одну итерацию по датасету, уменьшив скорость обучения в 10 раз
acc = model.iterate_file(update_vocab=False, learning_rate=0.01)
print('%0.2f' % acc)
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());
# Out:
# 0.00
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Ответьте на вопрос,  к какому значению ближе всего полученное значение точности:
# <font color="red">Варианты ответа:</font>
# 1. 0.48
# 2. 0.58
# 3. 0.68
# 4. 0.78

# %% [markdown]
# ## 10. Прогнозирование тегов для новых вопросов
#
# В завершение сегодняшней домашки, вам предлагается реализовать метод `predict_proba`, который принимает строку,  содержащую вопрос, а возвращает список предсказанных тегов вопроса с их вероятностями.

# %%
# Обновите определение класса LogRegressor
# Ваш код здесь

# %%
model = LogRegressor()
acc = model.iterate_file(update_vocab=True)
print('%0.2f' % acc)
model.filter_vocab(n=10000)
acc = model.iterate_file(update_vocab=False, learning_rate=0.01)
print('%0.2f' % acc)

# %%
sentence = ("I want to improve my coding skills, so I have planned write " +
            "a Mobile Application.need to choose between Apple's iOS or Google's Android." +
            " my background: I have done basic programming in .Net,C/C++,Python and PHP " +
            "in college, so got OOP concepts covered. about my skill level, I just know " +
            "concepts and basic syntax. But can't write complex applications, if asked :(" +
            " So decided to hone my skills, And I wanted to know which is easier to " +
            "learn for a programming n00b. A) iOS which uses Objective C B) Android " + 
            "which uses Java. I want to decide based on difficulty level")

# %% [markdown]
# Ответьте на вопрос, какой или какие теги ассоциируются с данным вопросом, если порог принятия равен $0.9$?:
# <font color="red">Варианты ответа:</font>
# 1. android
# 2. ios
# 3. ios, php
# 4. c#, c++, ods
